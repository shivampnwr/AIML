# %%
# grid(): helps make plts easier to read by adding refernce lines
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4,5]
y=[20,25,30,35,40]

# %%
plt.plot(x,y)
plt.grid(axis="y",color="lightgrey",linewidth=4,linestyle="dashed")
